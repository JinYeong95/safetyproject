# %%
import os
import matplotlib.image as mpimg

# %%
import json

# JSON 파일을 읽어서 파이썬 데이터 구조로 변환하기
with open('S2-N0504M00910.json', 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)
print(data)
# Out:
# {'image': {'date': '20201013', 'path': 'S2-N0504M00001', 'filename': 'S2-N0504M00910.jpg', 'copyrighter': '미디어그룹사람과숲(컨)', 'H_DPI': 96, 'location': '05', 'V_DPI': 96, 'bit': '24', 'resolution': [1920, 1080]}, 'annotations': [{'data ID': 'S2', 'middle classification': '01', 'flags': {}, 'box': [870, 119, 1204, 468], 'class': '01'}, {'data ID': 'S2', 'middle classification': '01', 'flags': {}, 'box': [938, 721, 1112, 1059], 'class': '05'}, {'data ID': 'S2', 'middle classification': '01', 'flags': {}, 'box': [891, 0, 1038, 162], 'class': '07'}, {'data ID': 'S2', 'middle classification': '01', 'flags': {}, 'box': [1371, 204, 1468, 318], 'class': '01'}, {'data ID': 'S2', 'middle classification': '01', 'flags': {}, 'box': [1368, 365, 1463, 467], 'class': '05'}, {'data ID': 'S2', 'middle classification': '01', 'flags': {}, 'box': [1615, 185, 1692, 259], 'class': '02'}, {'polygon': [[952, 493], [930, 495], [912, 488], [891, 488], [866, 496], [846, 498], [839, 507], [820, 510], [806, 515], [79
# ...

# %%
current = os.getcwd()
current
# Out:
# 'C:\\Users\\강진영\\Desktop\\하남공사'

# %%
folder_path = "C:\\Users\\강진영\\Desktop\\하남공사\\1.하남이미지옮기기1-2"
photo = "S2-N0504M00911.jpg"

# %%
photo_path = os.path.join(folder_path, photo)

# %%
photo_path
# Out:
# 'C:\\Users\\강진영\\Desktop\\하남공사\\1.하남이미지옮기기1-2\\S2-N0504M00911.jpg'

# %%
if os.path.exists(photo_path):
    print(f"The file '{photo}' exists at '{photo_path}'.")
else:
    print(f"The file '{photo}' does not exist at '{photo_path}'.")
# Out:
# The file 'S2-N0504M00911.jpg' exists at 'C:\Users\강진영\Desktop\하남공사\1.하남이미지옮기기1-2\S2-N0504M00911.jpg'.

# %%
import cv2

# %%
photo_path
# Out:
# 'C:\\Users\\강진영\\Desktop\\하남공사\\1.하남이미지옮기기1-2\\S2-N0504M00911.jpg'

# %%
img = cv2.imread(photo_path)

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

folder_path = "C:\\Users\\강진영\\Desktop\\하남공사\\1.하남이미지옮기기1-2"
photo = "S2-N0504M00911.jpg"

photo_path = os.path.join(folder_path, photo)

# 이미지 불러오기
img = mpimg.imread(photo_path)

# 이미지 표시
plt.imshow(img)
plt.axis('off')  # 축 표시 비활성화
plt.show()

# %%
json_folder = 'C:\\Users\\강진영\\Desktop\\하남공사'
json_file = "S2-N0504M00910.json"

# %%
total_json = os.path.join(json_folder, json_file)
total_json
# Out:
# 'C:\\Users\\강진영\\Desktop\\하남공사\\S2-N0504M00910.json'

# %%
# JSON 파일을 읽어서 파이썬 데이터 구조로 변환하기
with open(total_json, 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# 읽어온 데이터 사용하기
print(data.keys())
# Out:
# dict_keys(['image', 'annotations'])

# %%
data['annotations'][0]['box']
# class 01 = 안전조끼
# Out:
# [870, 119, 1204, 468]

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

folder_path = "C:\\Users\\강진영\\Desktop\\하남공사\\1.하남이미지옮기기1-2"
photo = "S2-N0504M00911.jpg"

photo_path = os.path.join(folder_path, photo)

# 이미지 불러오기
img = mpimg.imread(photo_path)

# 이미지 표시
plt.imshow(img)
plt.axis('off')  # 축 표시 비활성화

# Bounding box 좌표
x, y, width, height = 870, 119, 1204-870, 468-119

# Bounding box 그리기
rect = patches.Rectangle((x, y), width, height, linewidth=1, edgecolor='r', facecolor='none')
plt.gca().add_patch(rect)

plt.show()

# %%
data['annotations'][0]['box']
# 0번의 경우 안전조끼
# class 01번이였음
# Out:
# [870, 119, 1204, 468]

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

folder_path = "C:\\Users\\강진영\\Desktop\\하남공사\\1.하남이미지옮기기1-2"
photo = "S2-N0504M00911.jpg"

photo_path = os.path.join(folder_path, photo)

# 이미지 불러오기
img = mpimg.imread(photo_path)

# 이미지 표시
plt.imshow(img)
plt.axis('off')  # 축 표시 비활성화

# Bounding box 좌표
boxes = [[938, 721, 1112 - 938, 1059 - 721],   # 첫 번째 bounding box
         [870, 119, 1204-870, 468-119]]  # 두 번째 bounding box

# Bounding box 그리기
for box in boxes:
    x, y, width, height = box
    rect = patches.Rectangle((x, y), width, height, linewidth=1, edgecolor='r', facecolor='none')
    plt.gca().add_patch(rect)

plt.show()

# %%
data['annotations'][2]['box']
# 2번의 경우 안전모인듯하다
# class 07이 안전모
# Out:
# [891, 0, 1038, 162]

# %%
data['annotations'][4]['box']
# Out:
# [1368, 365, 1463, 467]

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

folder_path = "C:\\Users\\강진영\\Desktop\\하남공사\\1.하남이미지옮기기1-2"
photo = "S2-N0504M00911.jpg"

photo_path = os.path.join(folder_path, photo)

# 이미지 불러오기
img = mpimg.imread(photo_path)

# 이미지 표시
plt.imshow(img)
plt.axis('off')  # 축 표시 비활성화

# Bounding box 좌표
x, y, width, height = 1368, 365, 1463-1368, 467-365

# Bounding box 그리기
rect = patches.Rectangle((x, y), width, height, linewidth=1, edgecolor='r', facecolor='none')
plt.gca().add_patch(rect)

plt.show()

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

folder_path = "C:\\Users\\강진영\\Desktop\\하남공사\\1.하남이미지옮기기1-2"
photo = "S2-N0504M00911.jpg"

photo_path = os.path.join(folder_path, photo)

# 이미지 불러오기
img = mpimg.imread(photo_path)

# 이미지 표시
plt.imshow(img)
plt.axis('off')  # 축 표시 비활성화

# Bounding box 좌표
x, y, width, height = 891, 0, 1038-891, 162 -0

# Bounding box 그리기
rect = patches.Rectangle((x, y), width, height, linewidth=1, edgecolor='r', facecolor='none')
plt.gca().add_patch(rect)

plt.show()

# %%
# folder_path = "C:\\Users\\Administrator\\Desktop\\Photos\\공사현장 안전장비 인식 이미지\\Training\\[원천]2.공연장_부산 오페라 하우스 신축공사"
# photo = "S2-O1301M00065.jpg"

# photo_path = os.path.join(folder_path, photo)

# %%
# json_folder = "C:\\Users\\Administrator\\Desktop\\Photos\\105.공사현장 안전장비 인식 데이터\\01.데이터\\1.Training\\라벨링데이터(zip)_230328_add\\부산 오페라 하우스 신축공사\\5.전체"
# json_file = "S2-O1301M00065.json"

# total_json = os.path.join(json_folder, json_file)
# total_json
# Out:
# 'C:\\Users\\Administrator\\Desktop\\Photos\\105.공사현장 안전장비 인식 데이터\\01.데이터\\1.Training\\라벨링데이터(zip)_230328_add\\부산 오페라 하우스 신축공사\\5.전체\\S2-O1301M00065.json'

# %%
# JSON 파일을 읽어서 파이썬 데이터 구조로 변환하기
with open(total_json, 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# 읽어온 데이터 사용하기
print(data.keys())
print(data['annotations'])

annotations = data['annotations']
# Out:
# dict_keys(['image', 'annotations'])
# ...

# %%
polygons = [annotation["polygon"] for annotation in data["annotations"] if "polygon" in annotation]

print(polygons)
# Out:
# [[[952, 493], [930, 495], [912, 488], [891, 488], [866, 496], [846, 498], [839, 507], [820, 510], [806, 515], [795, 516], [781, 516], [763, 513], [743, 510], [727, 505], [714, 502], [699, 497], [690, 493], [679, 487], [667, 480], [651, 474], [644, 471], [631, 468], [617, 465], [606, 462], [594, 460], [582, 458], [568, 455], [557, 453], [549, 453], [543, 460], [549, 470], [554, 474], [575, 483], [587, 486], [598, 488], [624, 495], [631, 496], [658, 500], [675, 502], [692, 507], [701, 508], [718, 515], [732, 519], [746, 522], [761, 526], [782, 529], [803, 530], [814, 531], [837, 529], [851, 524], [870, 521], [888, 514], [908, 513], [932, 514], [946, 517], [953, 516], [954, 506]]]

# %%
for annotation in annotations:
    for key in keys:
        if key in annotation and annotation[key]:
            if key == 'box':
                boxes.append(annotation[key])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23528\2514747981.py in <module>
#       1 for annotation in annotations:
# ----> 2     for key in keys:
#       3         if key in annotation and annotation[key]:
#       4             if key == 'box':
#       5                 boxes.append(annotation[key])
#
# NameError: name 'keys' is not defined

# %%
boxes
# Out:
# [[938, 721, 174, 338], [870, 119, 334, 349]]

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

folder_path = "C:\\Users\\강진영\\Desktop\\하남공사\\1.하남이미지옮기기1-2"
photo = "S2-N0504M00911.jpg"

photo_path = os.path.join(folder_path, photo)

# 이미지 불러오기
img = mpimg.imread(photo_path)

# 이미지 표시
plt.imshow(img)
plt.axis('off')  # 축 표시 비활성화

# Polygon 좌표
    # 다른 polygons 좌표도 추가 가능
polygons = [[[952, 493], [930, 495], [912, 488], [891, 488], [866, 496], [846, 498], [839, 507], [820, 510], [806, 515], [795, 516], 
      [781, 516], [763, 513], [743, 510], [727, 505], [714, 502], [699, 497], [690, 493], [679, 487], [667, 480], [651, 474], 
      [644, 471], [631, 468], [617, 465], [606, 462], [594, 460], [582, 458], [568, 455], [557, 453], [549, 453], [543, 460], 
      [549, 470], [554, 474], [575, 483], [587, 486], [598, 488], [624, 495], [631, 496], [658, 500], [675, 502], [692, 507], 
      [701, 508], [718, 515], [732, 519], [746, 522], [761, 526], [782, 529], [803, 530], [814, 531], [837, 529], [851, 524], 
      [870, 521], [888, 514], [908, 513], [932, 514], [946, 517], [953, 516], [954, 506]]]

# Polygon 그리기
for polygon in polygons:
    polygon_points = [(x, y) for x, y in polygon]
    poly = patches.Polygon(polygon_points, closed=True, linewidth=1, edgecolor='r', facecolor='none')
    plt.gca().add_patch(poly)

plt.show()
