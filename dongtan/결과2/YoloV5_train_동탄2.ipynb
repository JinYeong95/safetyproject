# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# !pip install -r requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15926, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 15926 (delta 21), reused 29 (delta 13), pack-reused 15880
# Receiving objects: 100% (15926/15926), 14.66 MiB | 10.09 MiB/s, done.
# Resolving deltas: 100% (10920/10920), done.
# /content/yolov5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.5/609.5 kB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.4 MB/s eta 0:00:00
# ...

# %%
# !unzip "/content/drive/MyDrive/공사현장 인식 프로젝트/1번데이터_동탄.zip" -d "/content/yolov5"
# Out:
# Archive:  /content/drive/MyDrive/공사현장 인식 프로젝트/1번데이터_동탄.zip
#    creating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/
#    creating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00003.jpg
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00005.jpg
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00137.jpg
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00138.jpg
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00139.jpg
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00140.jpg
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00141.jpg
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00157.jpg
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00158.jpg
#   inflating: /content/yolov5/1╣°╡е└╠┼═_╡┐┼║/train/images/S2-N0002M00159.jpg
# ...

# %%
yaml_content = """
train: /content/yolov5/dongtan/train
val: /content/yolov5/dongtan/train

nc: 4
names: ['off_harness', 'on_harness', 'off_helmet', 'on_helmet']
"""

with open('/content/yolov5/data/custom.yaml', 'w') as f:
    f.write(yaml_content)

# %%
# !python train.py  --weights "/content/drive/MyDrive/공사현장 인식 프로젝트/best.pt" --data "/content/yolov5/data/custom.yaml" --epochs 30
# Out:
# train: weights=/content/drive/MyDrive/공사현장 인식 프로젝트/best.pt, cfg=, data=/content/yolov5/data/custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !zip -r train_result_dongtan2.zip /content/yolov5/runs/train/exp
# !unzip "/content/yolov5/train_result.zip" -d "/content/"
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/P_curve.png (deflated 11%)
#   adding: content/yolov5/runs/train/exp/labels.jpg (deflated 32%)
#   adding: content/yolov5/runs/train/exp/train_batch0.jpg (deflated 7%)
#   adding: content/yolov5/runs/train/exp/val_batch1_labels.jpg (deflated 10%)
#   adding: content/yolov5/runs/train/exp/PR_curve.png (deflated 18%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 50%)
#   adding: content/yolov5/runs/train/exp/confusion_matrix.png (deflated 27%)
#   adding: content/yolov5/runs/train/exp/val_batch1_pred.jpg (deflated 9%)
#   adding: content/yolov5/runs/train/exp/events.out.tfevents.1692862782.385652c30233.2185.0 (deflated 31%)
#   adding: content/yolov5/runs/train/exp/labels_correlogram.jpg (deflated 45%)
#   adding: content/yolov5/runs/train/exp/F1_curve.png (deflated 9%)
#   adding: content/yolov5/runs/train/exp/results.csv (deflated 82%)
# ...

# %%
# !python detect.py --source /content/drive/MyDrive/공사현장\ 인식\ 프로젝트/KakaoTalk_20230820_111646242.mp4

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/best.pt" --source "/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/281) /content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4: 640x384 1 on_helmet, 71.2ms
# video 1/1 (2/281) /content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4: 640x384 1 off_harness, 7.7ms
# ...
