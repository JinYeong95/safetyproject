# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# !pip install -r requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15927, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 15927 (delta 21), reused 30 (delta 13), pack-reused 15880
# Receiving objects: 100% (15927/15927), 14.66 MiB | 20.94 MiB/s, done.
# Resolving deltas: 100% (10920/10920), done.
# /content/yolov5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.9/608.9 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
# ...

# %%
# !mkdir -p "/content/yolov5/4300file/images"

# %%
# !mkdir -p "/content/yolov5/4300file/labels"

# %%
# !unzip "/content/drive/MyDrive/공사현장 인식 프로젝트/labels_only2.Zip" -d "/content/yolov5/4300file/labels"
# Out:
# Archive:  /content/drive/MyDrive/공사현장 인식 프로젝트/labels_only2.Zip
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48104.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48306.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48318.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48348.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48350.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48368.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48434.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48614.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48798.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48830.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M48942.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M49072.txt
#   inflating: /content/yolov5/4300file/labels/S2-N2101M49196.txt
# ...

# %%
# !unzip "/content/drive/MyDrive/공사현장 인식 프로젝트/images_only2.Zip" -d "/content/yolov5/4300file/images"
# Out:
# Archive:  /content/drive/MyDrive/공사현장 인식 프로젝트/images_only2.Zip
#   inflating: /content/yolov5/4300file/images/S2-N2101M48104.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48306.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48318.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48348.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48350.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48368.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48434.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48614.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48798.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48830.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M48942.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M49072.jpg
#   inflating: /content/yolov5/4300file/images/S2-N2101M49196.jpg
# ...

# %%
import os

# %%
len(os.listdir("/content/yolov5/4300file/images"))
# Out:
# 4268

# %%
len(os.listdir("/content/yolov5/4300file/labels"))
# Out:
# 4268

# %%
# 같은지 확인


labels_folder = "/content/yolov5/4300file/labels"
images_folder = "/content/yolov5/4300file/images"

labels_files = os.listdir(labels_folder)
images_files = os.listdir(images_folder)

common_names = set(name.split('.')[0] for name in labels_files) & set(name.split('.')[0] for name in images_files)

same_count = 0
different_count = 0

for name in common_names:
    if len(name) == len(images_files[0].split('.')[0]):
        same_count += 1
    else:
        different_count += 1

different_count += len(labels_files) - len(common_names)

print(f"Number of names with the same count: {same_count}")
print(f"Number of names with a different count: {different_count}")
# Out:
# Number of names with the same count: 4268
# Number of names with a different count: 0

# %%
yaml_content = """
train: /content/yolov5/4300file
val: /content/yolov5/4300file

nc: 4
names: ['off_harness', 'on_harness', 'off_helmet', 'on_helmet']
"""

with open('/content/yolov5/data/custom.yaml', 'w') as f:
    f.write(yaml_content)

# %%
# !python train.py  --weights "/content/drive/MyDrive/공사현장 인식 프로젝트/outputimg3.pt" --data "/content/yolov5/data/custom.yaml" --epochs 40
# Out:
# train: weights=/content/drive/MyDrive/공사현장 인식 프로젝트/outputimg3.pt, cfg=, data=/content/yolov5/data/custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-212-g9974d51 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !zip -r train_result_epoch40_onlylabel.zip /content/yolov5/runs/train/exp
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/train_batch2.jpg (deflated 5%)
#   adding: content/yolov5/runs/train/exp/val_batch1_pred.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp/P_curve.png (deflated 13%)
#   adding: content/yolov5/runs/train/exp/train_batch0.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/exp/train_batch1.jpg (deflated 5%)
#   adding: content/yolov5/runs/train/exp/confusion_matrix.png (deflated 25%)
#   adding: content/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/weights/best.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp/weights/last.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp/val_batch2_labels.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp/labels.jpg (deflated 29%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 50%)
# ...

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/best.pt" --source "/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4"

# 탐지하는 부분이에요! 앞에는 best.pt값 집어넣으시고, 뒤에는 해당 비디오 파일 집어넣으시면 yolo가 탐지합니다!
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-212-g9974d51 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/281) /content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4: 640x384 1 off_harness, 1 off_helmet, 41.3ms
# video 1/1 (2/281) /content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4: 640x384 1 off_harness, 1 off_helmet, 7.6ms
# ...

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/best.pt" --source "/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample2nd.mp4"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample2nd.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-212-g9974d51 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/304) /content/drive/MyDrive/공사현장 인식 프로젝트/videoexample2nd.mp4: 640x480 1 on_harness, 1 off_helmet, 68.1ms
# ...

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp/weights/best.pt" --source "/content/drive/MyDrive/공사현장 인식 프로젝트/mytest.mp4"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/공사현장 인식 프로젝트/mytest.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-212-g9974d51 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/157) /content/drive/MyDrive/공사현장 인식 프로젝트/mytest.mp4: 384x640 1 off_harness, 1 on_harness, 1 off_helmet, 94.8ms
# ...
