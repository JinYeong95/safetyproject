# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# !pip install -r requirements.txt  # install
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: 'yolov5'
# C:\Users\강진영\Desktop\공사현장\5번데이터
# fatal: Too many arguments.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     --reject-shallow      don't clone shallow repository
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     --recursive ...       alias of --recurse-submodules
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
# ...

# %%
yaml_content = """
train: /content/yolov5/data1/train/images
val: /content/yolov5/data1/train/images

nc: 4
names: ['off_harness', 'on_harness', 'off_helmet', 'on_helmet']
"""

with open('/content/yolov5/data/custom.yaml', 'w') as f:
    f.write(yaml_content)

# %%
# !python train.py --data "/content/yolov5/data/custom.yaml" --epochs 30
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# ...

# %%
# !zip -r train_result_dongtan.zip /content/yolov5/runs/train/exp2
# !unzip "/content/yolov5/train_result.zip" -d "/content/"
# Out:
#   adding: content/yolov5/runs/train/exp2/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/P_curve.png (deflated 12%)
#   adding: content/yolov5/runs/train/exp2/labels.jpg (deflated 32%)
#   adding: content/yolov5/runs/train/exp2/events.out.tfevents.1692844793.83c31cdc966e.3478.0 (deflated 31%)
#   adding: content/yolov5/runs/train/exp2/train_batch0.jpg (deflated 7%)
#   adding: content/yolov5/runs/train/exp2/val_batch1_labels.jpg (deflated 10%)
#   adding: content/yolov5/runs/train/exp2/PR_curve.png (deflated 18%)
#   adding: content/yolov5/runs/train/exp2/opt.yaml (deflated 49%)
#   adding: content/yolov5/runs/train/exp2/confusion_matrix.png (deflated 28%)
#   adding: content/yolov5/runs/train/exp2/val_batch1_pred.jpg (deflated 9%)
#   adding: content/yolov5/runs/train/exp2/labels_correlogram.jpg (deflated 45%)
#   adding: content/yolov5/runs/train/exp2/F1_curve.png (deflated 9%)
#   adding: content/yolov5/runs/train/exp2/results.csv (deflated 82%)
# ...

# %%
# !python detect.py --source /content/drive/MyDrive/공사현장\ 인식\ 프로젝트/KakaoTalk_20230820_111646242.mp4

# %%
# !python detect.py --weights "/content/yolov5/runs/train/exp2/weights/best.pt" --source "/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-211-g94e943e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/281) /content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4: 640x384 (no detections), 45.2ms
# video 1/1 (2/281) /content/drive/MyDrive/공사현장 인식 프로젝트/videoexample.mp4: 640x384 (no detections), 5.7ms
# ...
